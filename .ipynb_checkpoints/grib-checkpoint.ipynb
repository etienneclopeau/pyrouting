# %% [markdown]
# # pygrib test
# test du traitement de fichier grib

# %%
# Make the output of plotting commands be displayed inline within the notebook,
# %matplotlib notebook 
from mpl_toolkits.basemap import Basemap  # import Basemap matplotlib toolkit
import numpy as np
import matplotlib.pyplot as plt
import pygrib # import pygrib interface to grib_api

# %% [markdown]
# Open the grib file (downloaded from the NCAR TIGGE data portal

# %%
#dowload ftp://ftp.ncep.noaa.gov/pub/data/nccf/com/gfs/prod/gfs.2017032118/gfs.t18z.pgrb2.0p25.f006
#0p25 ou 0p50 ou 1p00 ou 2p50 

# https://nomads.ncdc.noaa.gov/dods/NCEP_NARR_DAILY/199601/19960101/narr-a_221_19960101_0000_000.ascii?rh2m[2][70:100][140:160]
# https://nomads.ncdc.noaa.gov/dods/NCEP_NARR_DAILY/199601/19960101/narr-a_221_19960101_0000_000.ascii?ugrdprs[0:7][16][90][320]
#http://www.globalmarinenet.com/free-grib-file-downloads/#download

# %%
grbs = pygrib.open('grib/NorthEurope.wind.7days.grb')

# %%
for grb in grbs[:10]:
    print(grb)
# Out:
# 1:U component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 6 hrs:from 201703231200
# 2:V component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 6 hrs:from 201703231200
# 3:U component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 12 hrs:from 201703231200
# 4:V component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 12 hrs:from 201703231200
# 5:U component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 18 hrs:from 201703231200
# 6:V component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 18 hrs:from 201703231200
# 7:U component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 24 hrs:from 201703231200
# 8:V component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 24 hrs:from 201703231200
# 9:U component of wind:m s**-1 (instant):regular_ll:surface:level 1:fcst time 30 hrs:from 201703231200
# ...

# %%
#print(grb.keys())

# %%
grbs.rewind()
for grb in grbs[:10]:
    print(grb.validityDate,grb.validityTime,grb.name)
# Out:
# 20170323 1800 U component of wind
# 20170323 1800 V component of wind
# 20170324 0 U component of wind
# 20170324 0 V component of wind
# 20170324 600 U component of wind
# 20170324 600 V component of wind
# 20170324 1200 U component of wind
# 20170324 1200 V component of wind
# 20170324 1800 U component of wind
# 20170324 1800 V component of wind

# %%
grbU, grbV = grbs[1:3]
#grb.latlons()
U, lats,lons = grbU.data()
V = grbV.data()[0]
print(U,V,lats,lons)
projd = grbU.projparams
print(projd)
# Out:
# [[13.43 11.9 10.370000000000001 ..., -- -- --]
#  [13.9 12.82 10.94 ..., -- -- --]
#  [13.23 12.64 11.8 ..., -- -- --]
#  ...,
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., -9.120000000000001 -5.54 -3.24]
#  [-- -- -- ..., -6.76 -3.97 -2.25]] [[5.5500146484375 4.1000146484375 3.6400146484375 ..., -- -- --]
#  [7.5700146484375 4.6900146484375 3.8400146484375 ..., -- -- --]
#  [8.6100146484375 4.4800146484375 4.2200146484375 ..., -- -- --]
#  ...,
#  [-- -- -- ..., -- -- --]
#  [-- -- -- ..., 10.4600146484375 9.7800146484375 11.1900146484375]
#  [-- -- -- ..., 7.8300146484375 8.5700146484375 9.4000146484375]] [[ 42.  42.  42. ...,  42.  42.  42.]
#  [ 43.  43.  43. ...,  43.  43.  43.]
#  [ 44.  44.  44. ...,  44.  44.  44.]
#  ...,
#  [ 70.  70.  70. ...,  70.  70.  70.]
#  [ 71.  71.  71. ...,  71.  71.  71.]
#  [ 72.  72.  72. ...,  72.  72.  72.]] [[-45.   -43.75 -42.5  ...,  22.5   23.75  25.  ]
#  [-45.   -43.75 -42.5  ...,  22.5   23.75  25.  ]
# ...

# %%
latmin = lats.min()
latmax = lats.max()
lonmin = lons.min()
lonmax = lons.max()

# %%
"""
fig2 = plt.figure(figsize=(8,10))
ax = fig2.add_axes([0.1,0.1,0.8,0.8])

# make orthographic basemap.
m = Basemap(resolution='c',projection=projd['proj'],lat_0=60.,lon_0=-60.)

# set desired contour levels.
clevs = np.arange(960,1061,5)
"""
ax.contourf(lats,lons,U)

# %%
#why is that so long...
# no issue found

plt.figure(figsize=(6,6))
#m = Basemap(projection='mill',
#            resolution='c',lat_1=latmin,lat_2=latmax,lat_0=(latmin+latmax)/2.,lon_0=(lonmin+lonmax)/2)
#m = Basemap(projection='mill',
#            llcrnrlat=latmin,urcrnrlat=latmax,\
#            llcrnrlon=lonmin,urcrnrlon=lonmax,
#            resolution='c')
m = Basemap(projection='mill',
            llcrnrlat=47,urcrnrlat=48,\
            llcrnrlon=-4,urcrnrlon=-2,
            resolution='h')
## draw coastlines.
m.drawcoastlines()
## draw a boundary around the map, fill the background.
## this background will end up being the ocean color, since
## the continents will be drawn on top.
#m.drawmapboundary(fill_color='aqua')
## fill continents, set lake color same as ocean color
#m.fillcontinents(color='coral',lake_color='aqua')

#m.shadedrelief()

# draw parallels and meridians.
# label parallels on right and top
# meridians on bottom and left
parallels = np.arange(40,60,1.)
# labels = [left,right,top,bottom]
m.drawparallels(parallels,labels=[False,True,True,False])
meridians = np.arange(-10.,10,1)
m.drawmeridians(meridians,labels=[True,False,False,True])

m.barbs(lons,lats,U,V, latlon = True)
# Out:
# <img src="data:image/png;base64,..." width="600">
# /home/etienne/anaconda3/envs/test/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3799: MatplotlibDeprecationWarning: The ishold function was deprecated in version 2.0.
#   b = ax.ishold()
# /home/etienne/anaconda3/envs/test/lib/python3.5/site-packages/mpl_toolkits/basemap/__init__.py:3815: MatplotlibDeprecationWarning: axes.hold is deprecated.
#     See the API Changes document (http://matplotlib.org/api/api_changes.html)
#     for more details.
#   ax.hold(b)
# (<matplotlib.quiver.Barbs at 0x7fc1ec2ae5f8>,
#  <matplotlib.quiver.Barbs at 0x7fc1ef103c88>)
